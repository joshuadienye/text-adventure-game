# %%
# importing necessary packages
import random
import time
import sys
from colorama import Fore

# code simulates typing slowly
def print_slow(str):
    for letter in str:
        sys.stdout.write(letter)
        sys.stdout.flush()
        time.sleep(0.1)

# code simulates typing fast
def print_fast(str):
    for letter in str:
        sys.stdout.write(letter)
        sys.stdout.flush()
        time.sleep(0.001)

# code for if the user loses the game
def game_end():
    print_fast(Fore.RED + """

    ▓██   ██▓ ▒█████   █    ██    ▓█████▄  ██▓▓█████ 
     ▒██  ██▒▒██▒  ██▒ ██  ▓██▒   ▒██▀ ██▌▓██▒▓█   ▀ 
      ▒██ ██░▒██░  ██▒▓██  ▒██░   ░██   █▌▒██▒▒███   
      ░ ▐██▓░▒██   ██░▓▓█  ░██░   ░▓█▄   ▌░██░▒▓█  ▄ 
      ░ ██▒▓░░ ████▓▒░▒▒█████▓    ░▒████▓ ░██░░▒████▒
       ██▒▒▒ ░ ▒░▒░▒░ ░▒▓▒ ▒ ▒     ▒▒▓  ▒ ░▓  ░░ ▒░ ░
     ▓██ ░▒░   ░ ▒ ▒░ ░░▒░ ░ ░     ░ ▒  ▒  ▒ ░ ░ ░  ░
     ▒ ▒ ░░  ░ ░ ░ ▒   ░░░ ░ ░     ░ ░  ░  ▒ ░   ░   
     ░ ░         ░ ░     ░           ░     ░     ░  ░
     ░ ░                           ░                 
       
""")   

# code for if the user wins the game    
def game_win():
        print_fast(Fore.BLUE + """
                                                                  ___   ___   ___  
                                                 .-.             (   ) (   ) (   ) 
 ___  ___    .--.    ___  ___     ___  ___  ___ ( __)  ___ .-.    | |   | |   | |  
(   )(   )  /    \  (   )(   )   (   )(   )(   )(''") (   )   \   | |   | |   | |  
 | |  | |  |  .-. ;  | |  | |     | |  | |  | |  | |   |  .-. .   | |   | |   | |  
 | |  | |  | |  | |  | |  | |     | |  | |  | |  | |   | |  | |   | |   | |   | |  
 | '  | |  | |  | |  | |  | |     | |  | |  | |  | |   | |  | |   | |   | |   | |  
 '  `-' |  | |  | |  | |  | |     | |  | |  | |  | |   | |  | |   | |   | |   | |  
  `.__. |  | '  | |  | |  ; '     | |  ; '  | |  | |   | |  | |   |_|   |_|   |_|  
  ___ | |  '  `-' /  ' `-'  /     ' `-'   `-' '  | |   | |  | |   .-.   .-.   .-.  
 (   )' |   `.__.'    '.__.'       '.__.'.__.'  (___) (___)(___) (   ) (   ) (   ) 
  ; `-' '                                                         '-'   '-'   '-'  
   .__.'                                                                           
       
""" * 2)  

# code to print the princess word in third stage
def princess():
    print_fast(Fore.CYAN + """
      _____    _____    _____   _   _    _____   ______    _____    _____ 
     |  __ \  |  __ \  |_   _| | \ | |  / ____| |  ____|  / ____|  / ____|
     | |__) | | |__) |   | |   |  \| | | |      | |__    | (___   | (___  
     |  ___/  |  _  /    | |   | . ` | | |      |  __|    \___ \   \___ \ 
     | |      | | \ \   _| |_  | |\  | | |____  | |____   ____) |  ____) |
     |_|      |_|  \_\ |_____| |_| \_|  \_____| |______| |_____/  |_____/ 
    
""")
    
# code to print the prince word in third stage    
def prince():
    print_fast(Fore.CYAN + """
    .______   .______       __  .__   __.   ______  _______ 
    |   _  \  |   _  \     |  | |  \ |  |  /      ||   ____|
    |  |_)  | |  |_)  |    |  | |   \|  | |  ,----'|  |__   
    |   ___/  |      /     |  | |  . `  | |  |     |   __|  
    |  |      |  |\  \----.|  | |  |\   | |  `----.|  |____ 
    | _|      | _| `._____||__| |__| \__|  \______||_______|
    
""")
    
    
# the explanation stage of the game. A wizard appears and explains the 
# game while also getting specific information from the user
def game_start():
    
#docString
    """
    Created on Mon Oct 12 17:41:00 2020

    @author: joshua.dienye
    """

    """
    DocString:    

        A) Introduction: This game is based on the typical storyline of Mario Bros.
        Mario has to go through some trails in order to save the princess. This game
        takes that storyline and mixes it with that of the Monty Python movies. You must 
        win complete each trail to advance to the next. 

        Stage 1: The user must answer at least 2 out of 3 riddles    
        Stage 2: The user must defeat a dragon
        Stage 3: The user must choose the right princess

        B) Known Bugs and/or Errors:    
        None
    """
 
    # to print rumble seven times 
    print(Fore.MAGENTA + """RUMBLE!!!!! """ * 7)
    
    # activates time sleep to delay code from running for one second
    time.sleep(1)
    
    # code to print the dark wizard info fast 
    print_fast(Fore.MAGENTA + """ 
    
    ▓█████▄  ▄▄▄       ██▀███   ██ ▄█▀               
    ▒██▀ ██▌▒████▄    ▓██ ▒ ██▒ ██▄█▒                
    ░██   █▌▒██  ▀█▄  ▓██ ░▄█ ▒▓███▄░                
    ░▓█▄   ▌░██▄▄▄▄██ ▒██▀▀█▄  ▓██ █▄                
    ░▒████▓  ▓█   ▓██▒░██▓ ▒██▒▒██▒ █▄               
     ▒▒▓  ▒  ▒▒   ▓▒█░░ ▒▓ ░▒▓░▒ ▒▒ ▓▒               
     ░ ▒  ▒   ▒   ▒▒ ░  ░▒ ░ ▒░░ ░▒ ▒░               
     ░ ░  ░   ░   ▒     ░░   ░ ░ ░░ ░                
       ░          ░  ░   ░     ░  ░                  
     ░                                               
     █     █░ ██▓▒███████▒ ▄▄▄       ██▀███  ▓█████▄ 
    ▓█░ █ ░█░▓██▒▒ ▒ ▒ ▄▀░▒████▄    ▓██ ▒ ██▒▒██▀ ██▌
    ▒█░ █ ░█ ▒██▒░ ▒ ▄▀▒░ ▒██  ▀█▄  ▓██ ░▄█ ▒░██   █▌
    ░█░ █ ░█ ░██░  ▄▀▒   ░░██▄▄▄▄██ ▒██▀▀█▄  ░▓█▄   ▌
    ░░██▒██▓ ░██░▒███████▒ ▓█   ▓██▒░██▓ ▒██▒░▒████▓ 
    ░ ▓░▒ ▒  ░▓  ░▒▒ ▓░▒░▒ ▒▒   ▓▒█░░ ▒▓ ░▒▓░ ▒▒▓  ▒ 
      ▒ ░ ░   ▒ ░░░▒ ▒ ░ ▒  ▒   ▒▒ ░  ░▒ ░ ▒░ ░ ▒  ▒ 
      ░   ░   ▒ ░░ ░ ░ ░ ░  ░   ▒     ░░   ░  ░ ░  ░ 
        ░     ░    ░ ░          ░  ░   ░        ░    
                 ░                            ░      
    
""")
    
    print(Fore.MAGENTA + """*""" * 80)
    
    # a wizard approaches 
    print_slow(Fore.LIGHTGREEN_EX + """
An old looking wizard approaches you...
    """)
    
    print(Fore.BLACK + "")
    
    # code to get the name from the user 
    name = input(prompt = "WHO GOES THERE?!!! WHAT IS YOUR NAME?\t").capitalize().strip()
    
    # code to get where the user is from
    origin = input(prompt = "Where are you from?\t").capitalize().strip()
    
    # makes eye color global so we can use it in other stages 
    global eye_color
    
    # code to get the user's eye color 
    eye_color = input(prompt = "First of all, look in that lake and tell me the color of your eyes. What is the color?\t").lower().strip()

    #initializes the variable for tries
    tries_one = 5
    
    #loop for the choice of what the gender should be 
    while True:
        
        # subtracts tries_one by one after every pass
        tries_one -= 1
        
        # makes gender global so we can use it in other stages 
        global gender
        
        # code to choose who the user is looking for
        gender = input(prompt = """
        Who are you looking for?
        1. Prince
        2. Princess
        \n""").lower().strip()
        
        # if the user inputs wrong input 3 times, this prompt appears
        if tries_one == 2:
            print("Looks like you have a problem. Type '1' or 'prince' to choose a prince or type '2' or 'princess' to choose princess.")
            pass
        
        # if the user inputs wrong input 5 times, the game ends
        elif tries_one == 0:
            print("We are ending the game now. You can try again later")
            sys.exit()
            
        # if the user chooses this option, gender becomes prince 
        elif "one" in gender or "1" in gender or "1." in gender or "prince" in gender:
            gender = "prince"
            break
            
        # if the user chooses this option, gender becomes princess 
        elif "two" in gender or "2" in gender or "2." in gender or "princess" in gender:
            gender = "princess"
            break
            
        # this will catch any wrong input and return the user to the gender option
        else:
            print("Something went wrong")
            pass
    
    # prints * in a specific color
    print(Fore.MAGENTA +"""*""" * 80)
    
    # activates time sleep to delay code from running for one second
    time.sleep(1)
    
    # wizard introduces the game with some dynamic input 
    print_fast(Fore.BLACK + f"""
    AH! {name} from {origin}! I know who you are! I had a dream about you. 
    I had a dream that you are the chosen one. My dreams have never been wrong, but 
    I have a feeling you might be an impostor {name}! 
    I have made these challenges to test if you are worthy of the {gender}. 
   
    FIRST! 
    An immovable door blocks the path! 
    You must answer at least 2 of 3 riddles to gain entry to continue on your journey.

    SECOND! 
    You shall face the greatest enemy ever! 
    He is sooooo great that I had to pluck him from THE HOBBIT! 
    THE GREAT DRAGON SMAUG! 
    You must defeat him to continue on your journey.

    THIRD! 
    Since you are a knight sent from {origin}, you should know what the {gender} 
    looks like; the {gender}, whose eyes reflect your soul. 
    You will be presented with three options! You must choose which {gender} is the real one. 
    
    Also, I've lived a thousand millenia and in all my many years, I've discovered numbers
    are the easiest way to communicate. So if you see options with a number, just type it in! 
    I'll understand you quicker!!! And NO! It's not old age! -__- 
    
""")
    
    # prints * in a specific color
    print(Fore.MAGENTA +
"""*""" * 80)
    
    print(Fore.BLACK + "")
    
    #initializes the variable for tries
    tries_two = 5
    
    #loop for the user to choose if he wants to play or not 
    while True:
        
        # subtracts tries_two by one after every pass
        tries_two -= 1
        
        #code so the user chooses to start the game or not
        play_game = input(prompt = "Are you ready to start this journey? Yes or No?!\n").lower().strip()
        print("")
        
        # if the user inputs wrong input 3 times, this prompt appears
        if tries_two == 2:
            print("Looks like you have a problem. Type 'yes' or 'y' to start the game or type 'no' or 'n' to quit.")
            pass
        
        # if the user inputs wrong input 5 times, the game ends
        elif tries_two == 0:
            print("We are ending the game now. You can try again later")
            sys.exit()
        
        # if the user chooses this option, the game begins
        elif play_game == "yes" or play_game == "y":
            print("")
            stage_one()
            print(Fore.MAGENTA + """*""" * 80)
            break
            
        # if the user chooses this option, the game ends
        elif play_game == "no" or play_game == "n":
            print(Fore.MAGENTA + 
    """*""" * 80)
            print(Fore.RED + "\nGoodbye and never return!!!")
            sys.exit()
            
        # this will catch any wrong input and return the user to the start game option
        else:
            print(Fore.BLACK + "\nSomething went wrong")
            pass

# the first stage of the game. A door asks questions and the user is required
# to answer at least 2 out of 3 to be able to move to the next stage 
def stage_one():
    
    # activates time sleep to delay code from running for one second
    time.sleep(1)
    
    # prints * in a specific color
    print(Fore.YELLOW + 
"""*""" * 80)
    
    # code to print door slow
    print_fast(Fore.YELLOW + """
                     _,.---._       _,.---._                 
      _,..---._   ,-.' , -  `.   ,-.' , -  `.   .-.,.---.   
    /==/,   -  \ /==/_,  ,  - \ /==/_,  ,  - \ /==/  `   \  
    |==|   _   _\==|   .=.     |==|   .=.     |==|-, .=., | 
    |==|  .=.   |==|_ : ;=:  - |==|_ : ;=:  - |==|   '='  / 
    |==|,|   | -|==| , '='     |==| , '='     |==|- ,   .'  
    |==|  '='   /\==\ -    ,_ / \==\ -    ,_ /|==|_  . ,'.  
    |==|-,   _`/  '.='. -   .'   '.='. -   .' /==/  /\ ,  ) 
    `-.`.____.'     `--`--''       `--`--''   `--`-`--`--'    
    
""")
    
    # code to print door stage explanation fast
    print_fast(Fore.YELLOW + """So you chose to begin on this path! If you want to continue, you must
         answer at least 2 of 3 of my riddles!\n""")
    
    print("")
    
    # prints * in a specific color
    print(Fore.YELLOW + 
"""*""" * 80)
    
    print(Fore.BLACK + "")
    
    # list with all possible riddles and answers for the door stage 
    riddle = [
              ["During which month do people sleep the least?", "february"],
              ["I'm alive, but without breath; I'm as cold in life as in death; I'm never thirsty, though I always drink.", "a fish"],
              ["What gets wetter and wetter the more it dries?", "a towel"],
              ["What gets sharper the more you use it?", "the brain"],
              ["Which weighs more, a pound of feathers or a pound of bricks?", "neither — they both weigh a ton"],
              ["What has 13 hearts, but no other organs?", "a deck of cards"],
              ["What has a head and a tail, but no body?", "a coin"],
              ["At night they come without being fetched, and by day they are lost without being stolen.", "stars"],
              ["What is so delicate that saying its name breaks it?", "silence"],
              ["What kind of band never plays music?", "a rubber band"],
              ["What has to be broken before you can use it?", "an egg"],
              ["I have lakes with no water, mountains with no stone and cities with no buildings. What am I?", "a map"],
              ["You see me once in June, twice in November and not at all in May. What am I?", "e"],
              ["Why is 6 afraid of 7?", "because 7 8 9"],
              ["What is full of holes but still holds water?", "a sponge"],
              ["What kind of coat is best put on wet?", "a coat of paint"],
              ["What runs all around a backyard, yet never moves?", "a fence"]
             ]

    # initializing the variables
    tries = 0
    correct = 0
    tries_three = 5

    # loop to check if the user answers correctly 2 out of 3 times
    while tries < 4 or correct < 3:
        
        # if the user answers correctly twice, they win the stage 
        if correct == 2:
            print_slow(Fore.LIGHTGREEN_EX + "\nYou have completed this stage! You may continue on your path!!!\n")
            print("")
            stage_two()
            break
            
        # if the user answers more than two wrong, they lose the game
        elif (tries == 2 and correct == 0) or (tries == 2 and correct <1) or (tries == 3 and correct <= 1):
            
            # loop for the user to choose if he wants to play again or not 
            while True:
                
                # code so the user chooses if to play again or not
                try_again = input(prompt = "Do you want to try again? Yes or No?\t").lower()
                
                # subtracts tries_three by one after every pass
                tries_three -= 1
                
                # if the user inputs wrong input 3 times, this prompt appears
                if tries_three == 2:
                    print("Looks like you have a problem. Type 'yes' or 'y' to start again or type 'no' or 'n' to quit.")
                    pass
        
                # if the user inputs wrong input 5 times, the game ends
                elif tries_three == 0:
                    print("We are ending the game now. You can try again later")
                    sys.exit()
                
                # if user chooses this, the game starts again
                elif try_again == "yes" or try_again == "y":
                    print("" * 2)
                    game_start()
                
                # if user chooses this, the game ends
                elif try_again == "no" or try_again == "n":
                    print(Fore.RED + "\nGoodbye and never return!!!")
                    sys.exit()
                    
                # this will catch any wrong input and return the user to the start game option    
                else:
                    print(Fore.BLACK + "\nSomething went wrong")
                    pass
        
        # if number of times the user tries is less than 3, this block of code will run
        elif tries <=3:
            
            # a random question from the question list is chosen 
            question_one = random.choice(riddle)
            
            # prints the question that was chosen
            print(f"Your question is: \n{question_one[0]}")
            
            # code to get the answer from the user 
            answer_one = input("Answer the question:\n").casefold().strip()
            
            # prints * in a specific color
            print(Fore.MAGENTA + 
"""*""" * 80)
            
            # if the answer from the user is equal to the answer in the list
            # tries goes up by one and correct goes up by one
            # the question and answer are removed from the list
            if answer_one == question_one[1]:
                print("You got it right!")
                print(Fore.BLACK + "*" * 20)
                tries += 1
                correct += 1
                riddle.remove(question_one)
                
            # if the answer from the user is at least part of the answer in the list
            # tries goes up by one and correct goes up by one
            # the question and answer are removed from the list
            elif answer_one in question_one[1]:
                print("You didn't get it quite right but I'll give it to you!")
                print(Fore.BLACK + "*" * 20)
                tries += 1
                correct += 1
                riddle.remove(question_one)
                
            # if the answer from the user is not equal to the answer in the list
            # tries goes up by one
            # the question and answer are removed from the list
            elif answer_one not in question_one[1]:
                print("You have failed that question!")
                print(f"The correct answer was: {question_one[1]}")
                print(Fore.BLACK + "*" * 20)
                tries += 1
                riddle.remove(question_one)
                
        # this is to catch any bugs. returns the user to the beginning of the stage
        else:
            print(Fore.BLACK + "\nSomething went wrong")
            stage_one()

# the second stage of the game. A dragon appears and the user is meant to kill him
# by attacking the right part of the body
def stage_two():
    
    # prints * in a specific color
    print(Fore.RED + 
"""*""" * 80)
    
    # activates time sleep to delay code from running for one second
    time.sleep(1)
    
    # code to print dragon slow
    print_fast("""  
     (       (                            )       )  
     )\ )    )\ )     (       (        ( /(    ( /(  
    (()/(   (()/(     )\      )\ )     )\())   )\()) 
     /(_))   /(_)) ((((_)(   (()/(    ((_)\   ((_)\  
    (_))_   (_))    )\ _ )\   /(_))_    ((_)   _((_) 
     |   \  | _ \   (_)_\(_) (_)) __|  / _ \  | \| | 
     | |) | |   /    / _ \     | (_ | | (_) | | .` | 
     |___/  |_|_\   /_/ \_\     \___|  \___/  |_|\_| 
    
""")
    
    # prints * in a specific color
    print(Fore.RED +
"""*""" * 80)
    
    # list with all possible scenarios and answers for the dragon stage
    # split is used to take each string in answer element as a seperate string in a new list
    dragon = [
              [f"""
A golden dragon drops down with a mighty thud! His wings span the width of seven countries.
It's arm, though mangled, look as strong as the fasted horses. It looks at you with {eye_color}
eyes, eyes of total hate and destruction. A mighty gold jewel, the size of which you've never 
seen before, is buried in his chest. It screams, 'Why have you awaken me?!!!'""", "1 one arm arms".split()],
              [f"""
You look up to see a red dragon flapping his wings above you. The wings, although full
of holes, can carry his mighty weight. It suspends in the air and breathes fire up into
the sky! A mighty {eye_color} jewel, the size of which you've never seen before, is buried in
his chest. It screams, 'Why have you awaken me?!!!'""", "3 three wing wings".split()],
              [f"""
A dragon, the size of a small fox, comes out of a hole in the wall. Its wings look big enough to
enable it to fly. It looks fragile and weak, but it breathes fire as hot as a thousand suns. It's
stomach looks bloated, but it can still move quickly, and a pink jewel rests in its arm. It screams
in a mighty voice, 'Why have you awaken me?!!!'""", "2 two jewel".split()]
             ]
     
    #picks a random scenario from the list
    question_two = random.choice(dragon)
    
    print("")
    
    #prints the scenario
    print(Fore.BLACK + f"{question_two[0]}")
    
    
    #prints the options for the answers to the dragon scenarios
    print("""
    What part do you attack?
    1. Arms
    2. Jewel
    3. Wings
    4. Head
    """)
    
    # code to get the answer from the user 
    answer_two = input().casefold().strip()

    # prints - 
    print("-" * 20)
    
    # initializes the variable for tries_four
    # since the most number of characters in each answer is four
    # if the highest number of characters in answer is changed, this should be changed also
    tries_four = 4
    
    # loop to check if the users answer is correct
    for i in question_two[1]:
        
        # reduces tries_four by one
        tries_four -= 1
        
        # if tries equals to zero, the user's answer was not in the scenario answer list 
        if tries_four == 0:
            game_end()
            print("-"*20)
            
        # if the answer string is not in the user's answer, it gets skipped
        elif i not in answer_two:
            continue
        
        # if the answer string is in the user's answer, the user got it right and moves to next stage
        elif i in answer_two:
            print_slow(Fore.RED + "You killed the dragon! You may continue on your path!")
            print("")
            print(Fore.CYAN +
"""*""" * 80)
            stage_three()
            break
        
        # this is to catch any bugs. returns the user to the beginning of the stage
        else:
            print(Fore.BLACK + "\nSomething went wrong")
            stage_two()

#the third stage of the game. The user must choose which princess is the real one
def stage_three():
    
    # if gender previously chosen is princess print princess slowly
    if gender == "princess":
        princess()
        
    # if gender previously chosen is princess print princess slowly
    if gender == "prince":
        prince()
    
    # prints * in a specific color
    print(Fore.CYAN +
"""*""" * 80)
    
    # wizard shows up for the final round
    print_slow(Fore.LIGHTGREEN_EX + """
The old looking wizard approaches you again...
    """)
    
    #list with princess/prince options and answers
    princess_options = [
              [f"1. A twenty year old {gender} with bright golden hair, white eyes, the hieght of a tree and a turtle face"],
              [f"2. A twenty year old {gender} with bright golden hair, gold eyes, the hieght of a tree and a turtle face"],
              [f"""3. A twenty year old {gender} with bright golden hair, {eye_color} eyes, the hieght of a tree and a turtle face""", f"3 three {eye_color}".split()]
             ]
    
    #prints the wizard's question
    print_slow(Fore.BLACK + f"""
Now you must choose which one is the right {gender}.\n""")
       
    #prints the options the user can choose from
    for i in princess_options:
        print(i[0])
    
    #asks user to input answer
    princess_choice = input("""
What is your answer?\t""").lower().split()
    
    princess_answer = princess_options[2]
    
    # initializes the variable for tries_five
    # since the most number of characters in each answer is three
    # if the highest number of characters in answer is changed, this should be changed also
    tries_five = 3
    
    for i in princess_answer[1]:
        
        # reduces tries_five by one
        tries_five -= 1

        # if tries equals to zero, the user's answer was not in the princess options list 
        if tries_five == 0:
            game_end()
            print("-" * 20)
            
        # if the answer string is not in the user's answer, it gets skipped
        elif i not in princess_choice:
            continue
        
        # if the answer string is in the user's answer, the user got it right and moves to next stage
        elif i in princess_choice:
            game_win()
            break
        
        # this is to catch any bugs. returns the user to the beginning of the stage
        else:
            print(Fore.BLACK + "\nSomething went wrong")
            stage_three()


game_start()
